# %% [markdown]
# <a href="https://github.com/hafiz-kamilin/RWII-2026-/blob/main/%E7%AC%AC2%E9%80%B1/%E3%80%90%E6%BC%94%E7%BF%92%E3%80%91breastcancer_wisconsin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 決決定木を用いたBreast Cancer Wisconsinデータセットの分類と可視化

# %% [markdown]
# ## 課題1: データセットの読み込み
#
# - scikit-learnの `datasets` モジュールを用いてBreast Cancer Wisconsinデータセットを読み込みます。
# - 特徴量の名称を確認してください。このデータセットは 30次元（30個の特徴量）があります。
# - データの基本的な統計情報を確認します。
# - データセットを学習データとテストデータに分割します（例：80%を訓練データ，20%をテストデータ）。
#
# （ヒント）データセットの読み込み: `from sklearn.datasets import load_breast_cancer`

# %%
# ここにコードを追加してください

# %% [markdown]
# ## 課題2: 決定木モデルの構築
#
# - scikit-learnの `DecisionTreeClassifier` を用いて決定木分類器を実装します。ここでは `max_depth` を指定しないでください（＝デフォルト値である「無制限」を指定する）。
# - 訓練データを用いてモデルを訓練します。
#
# （ヒント）

# %%
# ここにコードを追加してください

# %% [markdown]
# ## 課題3: モデルの性能評価
#
# - テストデータを用いてモデルの性能を評価します。
# - 評価指標として正解率(accuracy)，適合率(precision)，再現率(recall)，F1スコアを計算します。
# - 混同行列を用いて，分類結果を可視化してください。

# %%
# ここにコードを追加してください

# %% [markdown]
# ## 課題4: 決定木の深さによる性能変化の分析
#
# - 決定木の最大深さ（ `max_depth` ）を変えながら，モデルの性能がどのように変化するか分析してください。 `max_depth` の値として [1, 3, 5, 7, 10, 15, 20, 50] を使用してください。
# - 各深さでの訓練データとテストデータに対する正解率をプロットし，過学習の観点から考察してください。

# %%
# ここにコードを追加してください

# %% [markdown]
# ## 課題5: 決定木の可視化と解釈
#
# - 課題4の結果，最適とされた `max_depth` の値を用いて，再度，決定木モデルを学習してください。その後，特徴量の重要度を計算し，どの特徴量が乳がんの診断に重要か考察してください。

# %%
# ここにコードを追加してください

# %% [markdown]
# ### 考察
