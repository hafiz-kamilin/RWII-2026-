# %% [markdown]
# <a href="https://colab.research.google.com/github/hafiz-kamilin/RWII-2026-/blob/main/%E7%AC%AC3%E9%80%B1/%E3%80%90%E6%BC%94%E7%BF%9202%E3%80%91SVM_exercise.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # サポートベクトルマシンを用いた分類実験

# %% [markdown]
# ## 1. Iris Dataset の練習

# %% [markdown]
# 以下では Iris dataset の場合のコードのみを示している。

# %%
# 必要なパッケージのインポート
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn.svm import SVC

# %% [markdown]
# ### 1.1. データセットの準備

# %%
# データセットの読み込み
iris = load_iris()
X, y = iris.data, iris.target

# データ分割
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# データの標準化
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### 1.2. SVMモデルの構築と評価

# %%
# SVMモデルを構築する関数
def train_and_evaluate_svm(X_train, X_test, y_train, y_test, kernel, C=1.0, degree=3, gamma='scale'):
    if kernel == 'poly':
        svm = SVC(kernel=kernel, C=C, degree=degree, gamma=gamma)
    else:
        svm = SVC(kernel=kernel, C=C, gamma=gamma)
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Kernel: {kernel}, Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))
    return svm, y_test, y_pred

# 関数でモデルを構築する
svm, y_test, y_pred = train_and_evaluate_svm(X_train_scaled, X_test_scaled, y_train, y_test, 'linear')

# 混同行列で可視化する
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=load_iris().target_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix (Linear SVM)")
plt.show()

# %% [markdown]
# ### 1.3. 異なるカーネル関数の比較

# %%
# 異なるカーネルでSVMを訓練・評価
kernels = ['linear', 'poly', 'rbf']
for kernel in kernels:
    train_and_evaluate_svm(X_train_scaled, X_test_scaled, y_train, y_test, kernel)

# %% [markdown]
# ### 1.4. ハイパーパラメータCの影響分析

# %%
c_values = [0.0001, 0.001, 0.01, 0.1, 10, 100]
accuracies = []

for c in c_values:
    svm = SVC(kernel='rbf', C=c)
    svm.fit(X_train_scaled, y_train)
    y_pred = svm.predict(X_test_scaled)
    score = accuracy_score(y_test, y_pred)
    print(f"C: {c}, Accuracy: {score:.2f}")
    accuracies.append(score) # この後の可視化のため，正解率をストック

# 一応可視化
plt.plot(c_values, accuracies)
plt.xscale('log')
plt.xlabel('C value')
plt.ylabel('Accuracy')
plt.title('SVM Performance vs C value (Iris dataset)')
plt.show()

# %% [markdown]
# ### 1.5. グリッドサーチによるハイパーパラメータの最適化

# %%
# 最適化したいハイパーパラメータの値
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 0.001, 0.01]
}

# グリッドサーチの実行（6-foldの場合 cv=6 ）
grid_search = GridSearchCV(svm, param_grid, cv=6, n_jobs=-1, verbose=1)
grid_search.fit(X_train_scaled, y_train)

# 最適パラメータとスコア表示
print("Best parameters:", grid_search.best_params_)
print(f"Best cross-validation accuracy: {grid_search.best_score_:.3f}")

# %% [markdown]
# ## 2. Ollivetti Faces Dataset の演習

# %% [markdown]
# 以下では Ollivetti Faces Dataset の場合の演習になる。

# %% [markdown]
# ### 2.1. データセットの準備
#
# - scikit-learnを使用して Olivetti Faces Dataset を読み込みます。
# - 訓練：テスト=75:25 に分割します。
# - SVM はスケールに敏感なため，データを標準化します。

# %%
from sklearn.datasets import fetch_olivetti_faces

# データセット取得
faces = fetch_olivetti_faces(shuffle=True)
X, y = faces.data, faces.target

# データ分割…




# データの標準化…

# %% [markdown]
# ### 2.2. 線形SVMの実装と評価
#
# - scikit-learnの`SVC`クラスを用いて線形SVMを実装します。使用するカーネルは`kernel='poly'`にします。
# - モデルを訓練して評価します。
# - 混同行列を作成し，分類性能を可視化します。しかし、`display_labels=None`にしてください。

# %%
# ここにコードを追加してください

# %% [markdown]
# ### 2.3. 異なるカーネル関数の比較
#
# - 線形カーネル，多項式カーネル，RBFカーネルを使用してSVMを実装します。
# - 各カーネルの性能を比較評価し，結果を考察します。

# %%
# ここにコードを追加してください

# %% [markdown]
# ## 2.4. ハイパーパラメータCの影響分析
#
# - 正則化パラメータ C の値を [0.1, 10, 100] と変えて，モデルの性能がどのように変化するか分析します。
# - SVMのカーネルは RBFカーネルを用いてください。

# %%
# ここにコードを追加してください

# %% [markdown]
# ## 2.5. グリッドサーチによるハイパーパラメータの最適化
#
# - SVMのカーネルは RBFカーネルを用いてください。
# - ハイパーパラメータ値の候補を次のとおりとします。
# - パラメータ C : [1, 10, 100]
# - パラメータ gamma : [’scale’, 0.001, 0.01, 0.1, 1]
# - グリッドサーチを用いて，最適パラメータ値を探索し，それを用いてテストデータを分類してください。

# %%
# ここにコードを追加してください
